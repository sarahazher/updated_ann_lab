# %%
# Write a Python Program using Perceptron Neural Network to recognise even and odd numbers. 
Given numbers are in ASCII form 0 to 9

import numpy as np

j = int(input("Enter a Number (0-9): "))
step_function = lambda x: 1 if x >= 0 else 0

training_data = [
    {'input': [1, 1, 0, 0, 0, 0], 'label': 1},
    {'input': [1, 1, 0, 0, 0, 1], 'label': 0}, 
    {'input': [1, 1, 0, 0, 1, 0], 'label': 1},
    {'input': [1, 1, 0, 1, 1, 1], 'label': 0}, 
    {'input': [1, 1, 0, 1, 0, 0], 'label': 1},
    {'input': [1, 1, 0, 1, 0, 1], 'label': 0}, 
    {'input': [1, 1, 0, 1, 1, 0], 'label': 1},
    {'input': [1, 1, 0, 1, 1, 1], 'label': 0}, 
    {'input': [1, 1, 1, 0, 0, 0], 'label': 1}, 
    {'input': [1, 1, 1, 0, 0, 1], 'label': 0}
]

weights = np.array([0, 0, 0, 0, 0, 1])

for data in training_data:
    input_data = np.array(data['input'])
    label = data['label']
    output = step_function(np.dot(input_data, weights))
    error = label - output
    weights += input_data * error

input_data = np.array([int(x) for x in list('{0:06b}'.format(j))])
output = "odd" if step_function(np.dot(input_data, weights)) == 0 else "even"
print(j, " is ", output)
# Out:
# Enter a Number (0-9):  3
# 3  is  odd

# %%
# import numpy as np
# This line imports the NumPy library, which is a popular library in Python used for numerical computing. It provides support for large, multi-dimensional arrays and matrices, along with a collection of mathematical functions to operate on these arrays.

# python
# Copy code
# j = int(input("Enter a Number (0-9): "))
# This line prompts the user to enter a number between 0 and 9 using the input() function, converts the input into an integer using int(), and stores it in the variable j.

# python
# Copy code
# step_function = lambda x: 1 if x >= 0 else 0
# This line defines a step function using a lambda function. A step function takes an input x and returns 1 if x is greater than or equal to 0, otherwise it returns 0. This function is later used to determine the output of the perceptron.

# python
# Copy code
# training_data = [
#     {'input': [1, 1, 0, 0, 0, 0], 'label': 1},
#     {'input': [1, 1, 0, 0, 0, 1], 'label': 0}, 
#     {'input': [1, 1, 0, 0, 1, 0], 'label': 1},
#     {'input': [1, 1, 0, 1, 1, 1], 'label': 0}, 
#     {'input': [1, 1, 0, 1, 0, 0], 'label': 1},
#     {'input': [1, 1, 0, 1, 0, 1], 'label': 0}, 
#     {'input': [1, 1, 0, 1, 1, 0], 'label': 1},
#     {'input': [1, 1, 0, 1, 1, 1], 'label': 0}, 
#     {'input': [1, 1, 1, 0, 0, 0], 'label': 1}, 
#     {'input': [1, 1, 1, 0, 0, 1], 'label': 0}
# ]
# This line defines a list of dictionaries called training_data. Each dictionary in this list represents a training example, where 'input' contains a list representing the input vector and 'label' contains the expected output label.

# python
# Copy code
# weights = np.array([0, 0, 0, 0, 0, 1])
# This line initializes the weights vector with zeros, except for the last element which is set to 1. This vector represents the weights of the perceptron model.

# python
# Copy code
# for data in training_data:
#     input_data = np.array(data['input'])
#     label = data['label']
#     output = step_function(np.dot(input_data, weights))
#     error = label - output
#     weights += input_data * error
# This block of code iterates through each training example in training_data. For each example, it calculates the output of the perceptron using the dot product of the input data and the weights vector. Then, it calculates the error by subtracting the predicted output from the actual label. Finally, it updates the weights using the input data and the error.

# python
# Copy code
# input_data = np.array([int(x) for x in list('{0:06b}'.format(j))])
# This line converts the input number j into a binary representation with 6 bits and stores it as an array of integers. It uses list comprehension to iterate over the characters of the binary representation and converts each character into an integer.

# python
# Copy code
# output = "odd" if step_function(np.dot(input_data, weights)) == 0 else "even"
# This line calculates the output of the perceptron for the input data input_data using the weights vector. If the output is 0, it assigns the string "odd" to the variable output; otherwise, it assigns "even".

# python
# Copy code
# print(j, " is ", output)
# This line prints the original input number j along with its classification result (odd or even).

# %%
# Objective:

# The objective of this Python program is to create a Perceptron Neural Network that can recognize whether a given number, represented in ASCII form (0 to 9), is even or odd. 
The program aims to demonstrate how a simple neural network model like the perceptron can be trained to perform binary classification tasks.

# Theory:

# A Perceptron is a type of artificial neuron that takes multiple binary inputs and produces a single binary output. It works by calculating the weighted sum of its inputs and applying a step function to determine the output.

# Here’s how it works:

# Inputs: Each input represents a feature of the data. In this program, the input is the ASCII representation of a number, which is a sequence of binary digits (0s and 1s).
# Weights: Each input is associated with a weight, which determines its importance in the calculation. These weights are initially set to zero.
# Weighted Sum: The weighted sum of the inputs is calculated by multiplying each input by its corresponding weight and then summing up the results.
# Activation Function: The weighted sum is then passed through an activation function. In this program, a step function is used. If the weighted sum is greater than or equal to zero, the output is 1; otherwise, it is 0.
# Training: The perceptron is trained using a set of labeled data. It adjusts its weights based on the errors between the predicted outputs and the actual labels. This adjustment helps the perceptron to make more accurate predictions in the future.
# Applications:

# Perceptrons are simple yet powerful models that have various applications in machine learning and artificial intelligence. Some common applications include:

# Pattern recognition: Perceptrons can be used to recognize patterns in data, such as handwritten digits, images, and text.
# Binary classification: They are effective in binary classification tasks, such as spam detection, sentiment analysis, and medical diagnosis.
# Control systems: Perceptrons can be used in control systems to make decisions based on sensor inputs.
# Robotics: They are used in robotics for tasks such as object detection, navigation, and path planning.
# Algorithm:

# The algorithm for training a perceptron to recognize even and odd numbers can be summarized as follows:

# Initialize weights: Initialize the weights vector with zeros.
# Define inputs and labels: Represent each number in ASCII form as a binary vector of length 7 (assuming ASCII representation of digits 0 to 9). Define labels for even and odd numbers.
# Define the activation function: Define a step function that returns 1 if the weighted sum is greater than or equal to zero, otherwise returns 0.
# Training loop: Iterate through the training data. For each example:
# Calculate the weighted sum of the inputs.
# Apply the activation function to get the predicted output.
# Calculate the error between the predicted output and the actual label.
# Update the weights based on the error.
# Testing: Given a new input number in ASCII form, convert it to a binary vector. Calculate the weighted sum using the trained weights and apply the activation function. If the output is 0, classify the number as even; otherwise, classify it as odd.
# This algorithm demonstrates how a perceptron can be trained to classify even and odd numbers based on their ASCII representation. With appropriate training data and tuning of parameters, 
#     the perceptron can achieve accurate classification results.








# Perceptron:

# A Perceptron is the simplest form of a neural network, mimicking the behavior of a single neuron. It receives multiple inputs, each multiplied by a weight, and produces a single output based on a threshold function. Mathematically, the output 
# �
# y of a perceptron is determined by the weighted sum of inputs:


#   are the corresponding weights.
# �
# b is the bias term.
# The step_function is typically a threshold function that outputs 1 if the weighted sum is greater than or equal to zero, and 0 otherwise.
# Training a Perceptron:

# The key to the Perceptron's functionality lies in its ability to learn from data. During training, the weights of the perceptron are adjusted iteratively to minimize the errors between the predicted outputs and the actual labels. This adjustment is typically done using the perceptron learning rule, which updates the weights based on the error:


#  .
# By iteratively adjusting the weights using this rule and presenting the perceptron with labeled training examples, the model gradually learns to correctly classify the data.

# Binary Classification:

# In the context of this program, the Perceptron is trained to perform binary classification, distinguishing between even and odd numbers. Each input instance (ASCII representation of a number) is associated with a label indicating whether the number is even or odd. The Perceptron learns to make this distinction by adjusting its weights based on the differences between its predictions and the true labels.

# Representation of Numbers in ASCII Form:

# The ASCII representation of numbers involves encoding each digit as a sequence of binary digits (0s and 1s). For example, the ASCII representation of the digit 0 is "00110000". Each binary digit in this representation serves as an input feature for the perceptron.

# Role of Activation Function:

# The activation function, typically a step function in a perceptron, introduces non-linearity to the model. It converts the weighted sum of inputs into a binary output, allowing the perceptron to make decisions based on thresholds. In this program, the step function ensures that the perceptron outputs 1 if the weighted sum is positive or zero, and 0 otherwise, effectively classifying numbers as even or odd.

# By understanding these theoretical concepts, we can design and implement an effective Perceptron Neural Network to recognize even and odd numbers based on their ASCII representations.
